# %%
import cv2 as cv
import PIL
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = 'result/Doan/Doan_0.png'

img = cv.imread(filename)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

fig, ax = plt.subplots(1, 1, figsize=(20,20))
ax.imshow(img)
plt.show()

# %%
# make copy and get dominant color
img_temp = img.copy()
unique, counts = np.unique(img_temp.reshape(-1, 3), axis=0, return_counts=True)
unique
# img_temp[:,:,0], img_temp[:,:,1], img_temp[:,:,2] = unique[np.argmax(counts)]

# np.array_equal(img_temp[0, 0], np.array([255, 255, 255]))
# Out:
# array([[  0,   0,   0],
#        [  0,   1,   1],
#        [  0,   2,   2],
#        ...,
#        [254, 255, 170],
#        [255, 255, 170],
#        [255, 255, 255]], dtype=uint8)

# %%
img_pil = PIL.Image.open('result/Doan/Doan_0.png')

# %%
color = img_pil.convert('RGB').getcolors()

# %%
color

# %%
color = PIL.Image.open('result/Doan/Doan_0.png').getcolors(img_pil.size[0]*img_pil.size[1])

# %%
colorcount = 0
for c in color:
    if c[0] > 10000:
        colorcount = colorcount + 1

# %%
colorcount
# Out:
# 5

# %%
type(color)
# Out:
# list
